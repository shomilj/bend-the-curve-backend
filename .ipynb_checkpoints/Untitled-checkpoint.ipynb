# %%
import requests

cookies = {
    'csrftoken': 'TT4RN1MuJKOdWCk5UXHDYllWbHfJeim4UzJxEPJV5fGFOZi8lpu3bLIr1KcFkHvE',
    'sessionid': 'd8ol96zvmyt4pm5d37g6khlxfxq7ou6h',
}

headers = {
    'Host': 'api.splashwithdolphin.com',
    'Content-Type': 'application/json',
    'Connection': 'close',
    'Accept': 'application/json',
    'User-Agent': 'DolphinApp-iOS/2.0.0.19',
    'Authorization': 'token a915d30d25b8055f5fb7b5c6293be23d0114b231',
    'Accept-Language': 'en-US;q=1.0',
    'Accept-Encoding': 'gzip, deflate',
}

params = (
    ('status', '2'),
    ('expand', 'company,job_type,location,title'),
    ('limit', '10000'),
    ('fields', 'id,status,title,is_active,company'),
)

response = requests.get('https://api.splashwithdolphin.com/api/v1/user-jobs/', headers=headers, params=params, cookies=cookies, verify=False)
# Out:
# /usr/local/lib/python3.7/site-packages/urllib3/connectionpool.py:851: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %%
response.json()
# Out:
# {'count': 28,
#  'results': [{'id': 278526,
#    'status': 2,
#    'title': 'Intern - Firmware Engineer- Summer 2020',
#    'isActive': True,
#    'company': {'id': 41,
#     'name': 'Xylem',
#     'description': '',
#     'url': 'https://www.xylem.com/en-us/',
#     'humanityProblems': [{'shortName': 'climate change'}]}},
#   {'id': 402494,
#    'status': 2,
#    'title': 'Intern: Data Analyst (Summer 2020)',
#    'isActive': True,
#    'company': {'id': 69,
#     'name': 'The Climate Corporation',
#     'description': '',
#     'url': 'https://climate.com/',
#     'humanityProblems': [{'shortName': 'climate change'}]}},
#   {'id': 414940,
#    'status': 2,
#    'title': 'Intern, Software Engineering, Lidar Systems',
#    'isActive': True,
#    'company': {'id': 3770,
#     'name': 'Waymo',
#     'description': '',
#     'url': 'https://waymo.com/',
#     'humanityProblems': [{'shortName': 'cities + mobility'}]}},
#   {'id': 396798,
#    'status': 2,
# ...
